# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha5386/CIE-1/blob/main/SEE_AIML_(22CS017).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
doc=nlp('Ai is a simulation of human intelligence it include nlp speech')
bigrams=ngrams(doc,2)
print(list(bigrams))
# Out:
# [(Ai, is), (is, a), (a, simulation), (simulation, of), (of, human), (human, intilligence), (intilligence, it), (it, include), (include, nlp), (nlp, speech)]

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
doc=nlp('Ai is a simulation of human intelligence it include nlp speech')
trigrams=ngrams(doc,3)
print(list(trigrams))
# Out:
# [(Ai, is, a), (is, a, simulation), (a, simulation, of), (simulation, of, human), (of, human, intilligence), (human, intilligence, it), (intilligence, it, include), (it, include, nlp), (include, nlp, speech)]
