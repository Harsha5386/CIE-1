# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha5386/CIE-1/blob/main/SEE_AIML_(22CS017).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
doc=('Ai is a simulation of human intelligence by machine . it include expects system nlp speech recognization')
bigrams=ngrams(doc,2)
print(list(bigrams))
# Out:
# [('A', 'i'), ('i', ' '), (' ', 'i'), ('i', 's'), ('s', ' '), (' ', 'a'), ('a', ' '), (' ', 's'), ('s', 'i'), ('i', 'm'), ('m', 'u'), ('u', 'l'), ('l', 'a'), ('a', 't'), ('t', 'i'), ('i', 'o'), ('o', 'n'), ('n', ' '), (' ', 'o'), ('o', 'f'), ('f', ' '), (' ', 'h'), ('h', 'u'), ('u', 'm'), ('m', 'a'), ('a', 'n'), ('n', ' '), (' ', 'i'), ('i', 'n'), ('n', 't'), ('t', 'e'), ('e', 'l'), ('l', 'l'), ('l', 'i'), ('i', 'g'), ('g', 'e'), ('e', 'n'), ('n', 'c'), ('c', 'e'), ('e', ' '), (' ', 'b'), ('b', 'y'), ('y', ' '), (' ', 'm'), ('m', 'a'), ('a', 'c'), ('c', 'h'), ('h', 'i'), ('i', 'n'), ('n', 'e'), ('e', ' '), (' ', '.'), ('.', ' '), (' ', 'i'), ('i', 't'), ('t', ' '), (' ', 'i'), ('i', 'n'), ('n', 'c'), ('c', 'l'), ('l', 'u'), ('u', 'd'), ('d', 'e'), ('e', ' '), (' ', 'e'), ('e', 'x'), ('x', 'p'), ('p', 'e'), ('e', 'c'), ('c', 't'), ('t', 's'), ('s', ' '), (' ', 's'), ('s', 'y'), ('y', 's'), ('s', 't'), ('t', 'e'), ('e', 'm'), ('m', ' '), (' ', 'n'), ('n', 'l'), ('l', 'p'), ('p', ' '), (' ', 's'), ('s', 'p'), ('p', 'e'), ('e', 'e'), ('e', 'c'), ('c', 'h'), ('h', ' '), (' ', 'r'), ('r', 'e'), ('e', 'c'), ('c', 'o'), ('o', 'g'), ('g', 'n'), ('n', 'i'), ('i', 'z'), ('z', 'a'), ('a', 't'), ('t', 'i'), ('i', 'o'), ('o', 'n')]

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
doc=('Ai is a simulation of human intelligence by . it include expects system nlp speech recognization')
trigrams=ngrams(doc,3)
print(list(trigrams))
# Out:
# [('A', 'i', ' '), ('i', ' ', 'i'), (' ', 'i', 's'), ('i', 's', ' '), ('s', ' ', 'a'), (' ', 'a', ' '), ('a', ' ', 's'), (' ', 's', 'i'), ('s', 'i', 'm'), ('i', 'm', 'u'), ('m', 'u', 'l'), ('u', 'l', 'a'), ('l', 'a', 't'), ('a', 't', 'i'), ('t', 'i', 'o'), ('i', 'o', 'n'), ('o', 'n', ' '), ('n', ' ', 'o'), (' ', 'o', 'f'), ('o', 'f', ' '), ('f', ' ', 'h'), (' ', 'h', 'u'), ('h', 'u', 'm'), ('u', 'm', 'a'), ('m', 'a', 'n'), ('a', 'n', ' '), ('n', ' ', 'i'), (' ', 'i', 'n'), ('i', 'n', 't'), ('n', 't', 'e'), ('t', 'e', 'l'), ('e', 'l', 'l'), ('l', 'l', 'i'), ('l', 'i', 'g'), ('i', 'g', 'e'), ('g', 'e', 'n'), ('e', 'n', 'c'), ('n', 'c', 'e'), ('c', 'e', ' '), ('e', ' ', 'b'), (' ', 'b', 'y'), ('b', 'y', ' '), ('y', ' ', '.'), (' ', '.', ' '), ('.', ' ', 'i'), (' ', 'i', 't'), ('i', 't', ' '), ('t', ' ', 'i'), (' ', 'i', 'n'), ('i', 'n', 'c'), ('n', 'c', 'l'), ('c', 'l', 'u'), ('l', 'u', 'd'), ('u', 'd', 'e'), ('d', 'e', ' '), ('e', ' ', 'e'), (' ', 'e', 'x'), ('e', 'x', 'p'), ('x', 'p', 'e'), ('p', 'e', 'c'), ('e', 'c', 't'), ('c', 't', 's'), ('t', 's', ' '), ('s', ' ', 's'), (' ', 's', 'y'), ('s', 'y', 's'), ('y', 's', 't'), ('s', 't', 'e'), ('t', 'e', 'm'), ('e', 'm', ' '), ('m', ' ', 'n'), (' ', 'n', 'l'), ('n', 'l', 'p'), ('l', 'p', ' '), ('p', ' ', 's'), (' ', 's', 'p'), ('s', 'p', 'e'), ('p', 'e', 'e'), ('e', 'e', 'c'), ('e', 'c', 'h'), ('c', 'h', ' '), ('h', ' ', 'r'), (' ', 'r', 'e'), ('r', 'e', 'c'), ('e', 'c', 'o'), ('c', 'o', 'g'), ('o', 'g', 'n'), ('g', 'n', 'i'), ('n', 'i', 'z'), ('i', 'z', 'a'), ('z', 'a', 't'), ('a', 't', 'i'), ('t', 'i', 'o'), ('i', 'o', 'n')]
